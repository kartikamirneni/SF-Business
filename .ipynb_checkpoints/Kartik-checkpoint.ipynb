# %%
# !pip install zipcode
# !pip install uszipcode
# !pip install xlrd
# Out:
# Requirement already satisfied: zipcode in c:\users\home\anaconda3\lib\site-packages (4.0.0)
# Requirement already satisfied: haversine in c:\users\home\anaconda3\lib\site-packages (from zipcode) (0.4.5)
# Requirement already satisfied: SQLAlchemy in c:\users\home\anaconda3\lib\site-packages (from zipcode) (1.1.9)
# Requirement already satisfied: uszipcode in c:\users\home\anaconda3\lib\site-packages (0.2.1)
# Requirement already satisfied: attrs in c:\users\home\anaconda3\lib\site-packages (from uszipcode) (18.2.0)
# Requirement already satisfied: pathlib-mate in c:\users\home\anaconda3\lib\site-packages (from uszipcode) (0.0.13)
# Requirement already satisfied: requests in c:\users\home\anaconda3\lib\site-packages (from uszipcode) (2.14.2)
# Requirement already satisfied: sqlalchemy in c:\users\home\anaconda3\lib\site-packages (from uszipcode) (1.1.9)
# Requirement already satisfied: xlrd in c:\users\home\anaconda3\lib\site-packages (1.0.0)

# %% [markdown]
# ### Since the city San Francisco is spelled different ways in the datasset, we just use another dataset containing San Francisco zipcodes to compare with the SF Business Dataset to extract all the businesses from San Francisco  without the hassle of string search

# %%
import pandas as pd
import numpy as np

sf_business_dataset = pd.read_csv("sf_business_dataset.csv", encoding='latin-1')
zip_codes_sf = pd.read_excel("zip_codes.xlsx")

# %%
sf_business_dataset.head()
# Out:
#       Location Id  Business Account Number       Ownership Name DBA Name  \
# 0  0026883-11-001                    26883  Chevron Texaco Corp  Chevron
# 1  0026883-12-001                    26883  Chevron Texaco Corp  Chevron
# 2  0026883-13-001                    26883  Chevron Texaco Corp  Chevron
# 3  0026883-15-001                    26883  Chevron Texaco Corp  Chevron
# 4  0026883-16-001                    26883  Chevron Texaco Corp  Chevron
#
#        Street Address           City State  Source Zipcode  \
# 0    2998 San Jose Av  San Francisco    CA         94112.0
# 1  301 Claremont Blvd  San Francisco    CA         94127.0
# 2     3675 Geary Blvd  San Francisco    CA         94118.0
# 3     2301 Lombard St  San Francisco    CA         94123.0
# 4        1288 19th St  San Francisco    CA         94107.0
#
#   Business Start Date Business End Date  \
# 0           10/1/1968               NaN
# 1           10/1/1968               NaN
# 2           10/1/1968               NaN
# 3           10/1/1968               NaN
# 4           10/1/1968               NaN
#
#                          ...                         NAICS Code  \
# 0                        ...                                NaN
# 1                        ...                                NaN
# 2                        ...                                NaN
# 3                        ...                                NaN
# 4                        ...                                NaN
#
#   NAICS Code Description Parking Tax Transient Occupancy Tax LIC Code  \
# 0                    NaN       False                   False      NaN
# 1                    NaN       False                   False      NaN
# 2                    NaN       False                   False      NaN
# 3                    NaN       False                   False      NaN
# 4                    NaN       False                   False      NaN
#
#   LIC Code Description Supervisor District  \
# 0                  NaN                11.0
# 1                  NaN                 7.0
# 2                  NaN                 1.0
# 3                  NaN                 2.0
# 4                  NaN                10.0
#
#   Neighborhoods - Analysis Boundaries  Business Corridor  \
# 0          Oceanview/Merced/Ingleside                NaN
# 1                  West of Twin Peaks                NaN
# 2                   Lone Mountain/USF                NaN
# 3                              Marina                NaN
# 4                        Potrero Hill                NaN
#
#                                    Business Location
# 0  2998 SAN JOSE AV\rSan Francisco, CA 94112\r(37...
# 1  301 CLAREMONT BLVD\rSan Francisco, CA 94127\r(...
# 2  3675 GEARY BLVD\rSan Francisco, CA 94118\r(37....
# 3  2301 LOMBARD ST\rSan Francisco, CA 94123\r(37....
# 4  1288 19TH ST\rSan Francisco, CA 94107\r(37.761...
#
# [5 rows x 26 columns]

# %% [markdown]
# # Q1

# %% [markdown]
# ## To identify high concentration of businesses in particular pockets of San Francisco

# %%
# Get Active Businesses by taking only those businesses having no end date

active_business = sf_business_dataset.loc[sf_business_dataset["Business End Date"].isnull(),:]
active_business.shape
# Out:
# (172670, 26)

# %% [markdown]
# ### Once we derive the businesses having no end date, we are assured that they are still active and have not closed down. Going down we narrow down those businesses to San Francisco.

# %%
# Get Active Businesses in San Francisco by comparing sf_business_dataset and zip_codes dataset

active_business_sf = active_business.loc[active_business["Source Zipcode"].isin(zip_codes_sf["zip"]),:]
active_business_sf["Source Zipcode"] = active_business_sf["Source Zipcode"].astype(int)

active_business_sf.shape
# Out:
# C:\Users\Home\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# (135031, 26)

# %% [markdown]
# ### We remove null entries of businesses whose location is not specified.

# %%
# Gather Business whose Business Location is specfied
active_business_sf_notnull = active_business_sf[active_business_sf["Business Location"].notnull()]
active_business_sf_notnull.shape
# Out:
# (114423, 26)

# %%
# To count number of businesses having null Business Location
active_business_sf["Business Location"].isnull().sum()
# Out:
# 20608

# %% [markdown]
# ### We see that only a minor portion of businesses do not have location specified. We then extract map coordinates from 'Business Location' attribute to plot on a map.

# %%
# Extract Lat & Long for Businesses having not null location

import re
lat_lon = []
def get_lat_lon(x):
    #print (x)
    z = re.search(r"[^[]*\(([^]]*)\)", x)
    if z is None:
        lat_lon.append('')
    else :
        lat_lon.append(z.group(1))
        
active_business_sf_notnull["Business Location"].apply(get_lat_lon)
len(lat_lon)
# Out:
# 114423

# %% [markdown]
# ### Split the coordinates column into latitude and longitude for map plot.

# %%
# New column in active_business_sf_notnull for Latitude & Longitude
active_business_sf_notnull = active_business_sf_notnull.assign(lat_lon = lat_lon)
active_business_sf_notnull["lat_lon"].head()
# Out:
# 0     37.711486, -122.45562
# 1      37.7405, -122.465095
# 2    37.781224, -122.458531
# 3    37.799337, -122.439665
# 4    37.761371, -122.395368
# Name: lat_lon, dtype: object

# %% [markdown]
# ### We create a seperate dataframe having no null values of latitude and longitude

# %%
# Split Latitude and Longitude into seperate column

new = active_business_sf_notnull["lat_lon"].str.split(',',n=2, expand = True)

# Drop NAs and None
new = new.replace([" ","",'None'], np.nan)
new = new.mask(new.eq('None')).dropna()

new.columns = ["lat","lon"]

new.head(5)
# Out:
#          lat           lon
# 0  37.711486    -122.45562
# 1    37.7405   -122.465095
# 2  37.781224   -122.458531
# 3  37.799337   -122.439665
# 4  37.761371   -122.395368

# %% [markdown]
# ### We then extract the missing coordinates from zipcode and fill the missing 20608 values with coordinates stored in a seperate dataframe.

# %%
## Get the info where Business Location == NULL 

from uszipcode import SearchEngine
search = SearchEngine(simple_zipcode=True)
#zip_code = search.by_zipcode('95050')
#zip_code

# %%
active_business_sf_isnull = active_business_sf[active_business_sf["Business Location"].isnull()]

# %%
# For 20k missing locations
active_business_sf_isnull["Source Zipcode"] = active_business_sf_isnull["Source Zipcode"].astype(int)
lat = active_business_sf_isnull["Source Zipcode"].map(lambda x : search.by_zipcode(x).to_dict()['lat'])
lng = active_business_sf_isnull["Source Zipcode"].map(lambda x : search.by_zipcode(x).to_dict()['lng'])
# Out:
# C:\Users\Home\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### Compare the size of the 3 dataframes created from the start.
# ### all_new is the final dataframe we are going to use as it does not have any empty latitude and longitude values.

# %%
new1 = pd.DataFrame(list(zip(lat.values.tolist(), lng.values.tolist())), columns= ["lat","lon"])
all_new = new.append(new1)
new.shape, new1.shape, all_new.shape
# Out:
# ((112822, 2), (20608, 2), (133430, 2))

# %% [markdown]
# ### We the drop the NA's and none to check the final length of all_new dataset. It comes down from 133430 to 128016

# %%
# Drop NAs,None and then check shape of coordinate dataset
all_new = all_new.replace([" ","",'None'], np.nan)
all_new = all_new.mask(new.eq('None')).dropna()
all_new.shape
# Out:
# (128016, 2)

# %%
all_new.head()
# Out:
#          lat           lon
# 0  37.711486    -122.45562
# 1    37.7405   -122.465095
# 2  37.781224   -122.458531
# 3  37.799337   -122.439665
# 4  37.761371   -122.395368

# %%
#Convert datatype to numeric
all_new = all_new.apply(pd.to_numeric)
all_new.dtypes
# Out:
# lat    float64
# lon    float64
# dtype: object

# %% [markdown]
# ### We convert the datatype of lat and lon to numeric so that folium does not consider them as string and throw error while plotting on map.

# %%
# Determine count of business within each zipcode
active_business_sf["Source Zipcode"].value_counts()
# Out:
# 94110    10455
# 94103     9755
# 94107     8355
# 94109     8138
# 94102     7145
# 94111     6028
# 94118     6013
# 94122     5890
# 94105     5683
# 94117     5661
# 94124     5614
# 94114     5568
# 94112     5542
# 94115     5464
# 94133     5454
# 94104     4989
# 94108     4977
# 94123     4919
# 94121     4343
# 94116     3544
# 94131     2759
# 94134     2473
# 94132     2209
# 94127     2167
# 94129      534
# 94158      519
# 94130      494
# 94188       67
# 94119       44
# 94142       39
# 94147       30
# 94143       24
# 94159       22
# 94120       21
# 94164       19
# 94141       19
# 94126       15
# 94140       11
# 94125        8
# 94137        6
# 94146        6
# 94177        5
# 94145        1
# 94144        1
# 94163        1
# Name: Source Zipcode, dtype: int64

# %% [markdown]
# ### We plot the the number of businesses by zipcode so as to get an estimate of difference in the quantity of business across each zipcode.

# %%
% matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(18, 15))
plt.title("# of Businesses by Source Zipcode", fontsize = 20)
plt.xlabel("Zip code in San Francisco", fontsize = 15)
plt.ylabel("# of Active Businesses", fontsize = 15)
active_business_sf["Source Zipcode"].value_counts().plot.bar()

# %% [markdown]
# ### The areas in San Francisco with the highest number of businesses are:-
# #### 94110 - Inner Mission/Bernal Heights
# #### 94103 - South of Market
# #### 94107 - Potrero Hill
# #### 94109 - Polk/Russian Hill (Nob Hill)
# #### 94102 - Hayes Valley/Tenderloin/North of Market

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\home\anaconda3\lib\site-packages (0.6.0)
# Requirement already satisfied: numpy in c:\users\home\anaconda3\lib\site-packages (from folium) (1.12.1)
# Requirement already satisfied: jinja2 in c:\users\home\anaconda3\lib\site-packages (from folium) (2.9.6)
# Requirement already satisfied: requests in c:\users\home\anaconda3\lib\site-packages (from folium) (2.14.2)
# Requirement already satisfied: branca>=0.3.0 in c:\users\home\anaconda3\lib\site-packages (from folium) (0.3.0)
# Requirement already satisfied: six in c:\users\home\anaconda3\lib\site-packages (from folium) (1.10.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\home\anaconda3\lib\site-packages (from jinja2->folium) (0.23)

# %%
import folium
from folium import plugins
from folium import features
import seaborn as sns

map = folium.Map(location=[37.711486,-122.45562], zoom_start=15)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
lats =[]
lons =[]
for each in all_new[0:len(all_new)].iterrows():
     lat = each [1]['lat']
     lats.append(lat)
     lon = each [1]['lon']
     lons.append(lon)
locations = list(zip(lats,lons))

map = folium.Map(location =[all_new['lat'].mean(),all_new['lon'].mean()],zoom_start =13)
folium.CircleMarker(location=locations ,radius=5).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#map = folium.Map(location =[all_new['lat'].mean(),all_new['lon'].mean()],zoom_start =13)

latitude =[]
longitude =[]
lat = all_new['lat']
lon = all_new['lon']

#map
latitude = list(lat.values)
longitude = list(lon.values)

locations = list(zip(latitude,longitude))


map = folium.Map(location = [all_new['lat'].mean(),  all_new['lon'].mean()], zoom_start=12)

for i in locations:
  folium.CircleMarker(location=i ,radius = 8, color = '#3186cc', fill_color='#3186cc').add_to(map)

map
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-4ecc396dfd44> in <module>()
#      18   folium.CircleMarker(location=i ,radius = 8, color = '#3186cc', fill_color='#3186cc').add_to(map)
#      19
# ---> 20 map
#
# C:\Users\Home\Anaconda3\lib\site-packages\IPython\core\displayhook.py in __call__(self, result)
#     244             self.start_displayhook()
#     245             self.write_output_prompt()
# --> 246             format_dict, md_dict = self.compute_format_data(result)
#     247             self.update_user_ns(result)
#     248             self.fill_exec_result(result)
#
# C:\Users\Home\Anaconda3\lib\site-packages\IPython\core\displayhook.py in compute_format_data(self, result)
#     148
#     149         """
# --> 150         return self.shell.display_formatter.format(result)
#     151
#     152     # This can be set to True by the write_output_prompt method in a subclass
#
# C:\Users\Home\Anaconda3\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     143             md = None
#     144             try:
# --> 145                 data = formatter(obj)
#     146             except:
#     147                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# C:\Users\Home\Anaconda3\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     188     """show traceback on failed format call"""
#     189     try:
# --> 190         r = method(self, *args, **kwargs)
#     191     except NotImplementedError:
#     192         # don't warn on NotImplementedErrors
#
# C:\Users\Home\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
#     312             return None
#     313         else:
#
# C:\Users\Home\Anaconda3\lib\site-packages\folium\folium.py in _repr_html_(self, **kwargs)
#     286             self._parent = None
#     287         else:
# --> 288             out = self._parent._repr_html_(**kwargs)
#     289         return out
#     290
#
# C:\Users\Home\Anaconda3\lib\site-packages\branca\element.py in _repr_html_(self, **kwargs)
#     317
#     318         """
# --> 319         html = self.render(**kwargs)
#     320         html = "data:text/html;charset=utf-8;base64," + base64.b64encode(html.encode('utf8')).decode('utf8')  # noqa
#     321
#
# C:\Users\Home\Anaconda3\lib\site-packages\branca\element.py in render(self, **kwargs)
#     307         """Renders the HTML representation of the element."""
#     308         for name, child in self._children.items():
# --> 309             child.render(**kwargs)
#     310         return self._template.render(this=self, kwargs=kwargs)
#     311
#
# C:\Users\Home\Anaconda3\lib\site-packages\folium\folium.py in render(self, **kwargs)
#     386             '</style>'), name='map_style')
#     387
# --> 388         super(Map, self).render(**kwargs)
#     389
#     390     def fit_bounds(self, bounds, padding_top_left=None,
#
# C:\Users\Home\Anaconda3\lib\site-packages\branca\element.py in render(self, **kwargs)
#     622
#     623         for name, element in self._children.items():
# --> 624             element.render(**kwargs)
#
# C:\Users\Home\Anaconda3\lib\site-packages\branca\element.py in render(self, **kwargs)
#     618         script = self._template.module.__dict__.get('script', None)
#     619         if script is not None:
# --> 620             figure.script.add_child(Element(script(self, kwargs)),
#     621                                     name=self.get_name())
#     622
#
# C:\Users\Home\Anaconda3\lib\site-packages\branca\element.py in __init__(self, template, template_name)
#      51
#      52         if template is not None:
# ---> 53             self._template = Template(template)
#      54         elif template_name is not None:
#      55             self._template = ENV.get_template(template_name)
#
# C:\Users\Home\Anaconda3\lib\site-packages\jinja2\environment.py in __new__(cls, source, block_start_string, block_end_string, variable_start_string, variable_end_string, comment_start_string, comment_end_string, line_statement_prefix, line_comment_prefix, trim_blocks, lstrip_blocks, newline_sequence, keep_trailing_newline, extensions, optimized, undefined, finalize, autoescape, enable_async)
#     943             frozenset(extensions), optimized, undefined, finalize, autoescape,
#     944             None, 0, False, None, enable_async)
# --> 945         return env.from_string(source, template_class=cls)
#     946
#     947     @classmethod
#
# C:\Users\Home\Anaconda3\lib\site-packages\jinja2\environment.py in from_string(self, source, globals, template_class)
#     878         globals = self.make_globals(globals)
#     879         cls = template_class or self.template_class
# --> 880         return cls.from_code(self, self.compile(source), globals, None)
#     881
#     882     def make_globals(self, d):
#
# C:\Users\Home\Anaconda3\lib\site-packages\jinja2\environment.py in compile(self, source, name, filename, raw, defer_init)
#     577             if isinstance(source, string_types):
#     578                 source_hint = source
# --> 579                 source = self._parse(source, name, filename)
#     580             source = self._generate(source, name, filename,
#     581                                     defer_init=defer_init)
#
# C:\Users\Home\Anaconda3\lib\site-packages\jinja2\environment.py in _parse(self, source, name, filename)
#     495     def _parse(self, source, name, filename):
#     496         """Internal parsing function used by `parse` and `compile`."""
# --> 497         return Parser(self, source, name, encode_filename(filename)).parse()
#     498
#     499     def lex(self, source, name=None, filename=None):
#
# C:\Users\Home\Anaconda3\lib\site-packages\jinja2\parser.py in __init__(self, environment, source, name, filename, state)
#      38                  state=None):
#      39         self.environment = environment
# ---> 40         self.stream = environment._tokenize(source, name, filename, state)
#      41         self.name = name
#      42         self.filename = filename
#
# C:\Users\Home\Anaconda3\lib\site-packages\jinja2\environment.py in _tokenize(self, source, name, filename, state)
#     527         """
#     528         source = self.preprocess(source, name, filename)
# --> 529         stream = self.lexer.tokenize(source, name, filename, state)
#     530         for ext in self.iter_extensions():
#     531             stream = ext.filter_stream(stream)
#
# C:\Users\Home\Anaconda3\lib\site-packages\jinja2\lexer.py in tokenize(self, source, name, filename, state)
#     556         """
#     557         stream = self.tokeniter(source, name, filename, state)
# --> 558         return TokenStream(self.wrap(stream, name, filename), name, filename)
#     559
#     560     def wrap(self, stream, name=None, filename=None):
#
# C:\Users\Home\Anaconda3\lib\site-packages\jinja2\lexer.py in __init__(self, generator, name, filename)
#     313         self.closed = False
#     314         self.current = Token(1, TOKEN_INITIAL, '')
# --> 315         next(self)
#     316
#     317     def __iter__(self):
#
# C:\Users\Home\Anaconda3\lib\site-packages\jinja2\lexer.py in __next__(self)
#     359         elif self.current.type is not TOKEN_EOF:
#     360             try:
# --> 361                 self.current = next(self._iter)
#     362             except StopIteration:
#     363                 self.close()
#
# C:\Users\Home\Anaconda3\lib\site-packages\jinja2\lexer.py in wrap(self, stream, name, filename)
#     562         every token in a :class:`Token` and converts the value.
#     563         """
# --> 564         for lineno, token, value in stream:
#     565             if token in ignored_tokens:
#     566                 continue
#
# C:\Users\Home\Anaconda3\lib\site-packages\jinja2\lexer.py in tokeniter(self, source, name, filename, state)
#     626                 # if no match we try again with the next rule
#     627                 if m is None:
# --> 628                     continue
#     629
#     630                 # we only match blocks and variables if braces / parentheses
#
# KeyboardInterrupt:

# %%
map = folium.Map(location =[all_new['lat'].mean(),all_new['lon'].mean()],zoom_start =13)
for i in [(37.811486, -122.47562), (37.711486, -122.45562)]:
  folium.CircleMarker(location =  i, radius = 5, color = '#3186cc', fill_color='#3186cc').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location =[all_new['lat'].mean(),all_new['lon'].mean()],zoom_start =13)
for i in locations[:2000]:
  folium.CircleMarker(location =  i, radius = 5, color = '#3186cc', fill_color='#3186cc').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Q2.

# %% [markdown]
# ## Determine the NAICS code and description of businesses to be benefitted from the tax break scheme

# %%
# Determine null values and number of businesses in each industry
active_business_sf["NAICS Code Description"].value_counts(dropna=False)
# Out:
# NaN                                                 45959
# Real Estate and Rental and Leasing Services         18937
# Professional, Scientific, and Technical Services    15689
# Retail Trade                                         8753
# Food Services                                        7197
# Transportation and Warehousing                       7014
# Private Education and Health Services                5467
# Construction                                         5039
# Arts, Entertainment, and Recreation                  4919
# Accommodations                                       3352
# Financial Services                                   2945
# Information                                          2501
# Wholesale Trade                                      2486
# Administrative and Support Services                  2353
# Manufacturing                                        1293
# Certain Services                                      540
# Insurance                                             487
# Utilities                                             100
# Name: NAICS Code Description, dtype: int64

# %% [markdown]
# ### We have 45,959 entries which are empty with respect to NAICS Code Description which is significantly high.

# %%
#Find number of null values in each attribute
sf_business_dataset.isnull().sum()
# Out:
# Location Id                                 0
# Business Account Number                     0
# Ownership Name                              0
# DBA Name                                    0
# Street Address                              4
# City                                      269
# State                                     680
# Source Zipcode                             97
# Business Start Date                         0
# Business End Date                      172670
# Location Start Date                         0
# Location End Date                      156405
# Mail Address                                2
# Mail City                                  52
# Mail Zipcode                              130
# Mail State                                119
# NAICS Code                              87716
# NAICS Code Description                  90199
# Parking Tax                                 0
# Transient Occupancy Tax                     0
# LIC Code                               206758
# LIC Code Description                   206758
# Supervisor District                     85847
# Neighborhoods - Analysis Boundaries     85852
# Business Corridor                      216383
# Business Location                       41278
# dtype: int64

# %% [markdown]
# ### We calculate null values based on both NAICS Code and Description entries. As the dataframe gives very lower number of null values, we go ahead to plot a bar graph for strength of industries based on number of businesses.

# %%
# Calculate null values in both NAICS Code and NAICS Code Description Values
active_business_sf[active_business_sf["NAICS Code Description"].isnull() & active_business_sf["NAICS Code"]].shape
# Out:
# (2245, 26)

# %%
# Plot a graph of strength of business in each industry
% matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 10))
plt.title("Types of business", fontsize = 20)
plt.xlabel("Industry", fontsize = 15)
plt.ylabel("# of Active Businesses", fontsize = 15)
active_business_sf["NAICS Code Description"].value_counts().plot.bar()

# %% [markdown]
# ### We can see the graph plotted and conclude that Utilities, Insurance, Certain Services, Manufacturing are the least popular industry categories in which businesses have come up in. We do not consider the 3-4 categories after Manufacturing as they are very similar in terms of number of businesses and it is a waste of resources to compare them.
# ### We can compare them if the analysis is to be done more deeply and on a minute basis.

# %%
# Creating a dataframe consisting of last 4 industry by business numbers and comparing it with the active businesses in San 
# Francisco dataset
less_pop=["Utilities","Insurance","Certain Services", "Manufacturing"]
df_less_pop=active_business_sf[active_business_sf["NAICS Code Description"].isin(less_pop)]
active_business_sf.shape,df_less_pop.shape
# Out:
# ((135031, 26), (2420, 26))

# %% [markdown]
# ### Above, we can see a comparison of the total number of businesses which are active in San Francisco to those which come in the above 4 categories.

# %% [markdown]
# # Active Businesses in Less popular industries by Year

# %%
# Creating a dataframe consisting of active businesses from the bottom 4 popular industries
df_less_pop=active_business_sf[active_business_sf["NAICS Code Description"].isin(less_pop)]

# %%
# We get the NAICS code and the size
df_less_pop.groupby(['NAICS Code',"NAICS Code Description"]).size()
# Out:
# NAICS Code  NAICS Code Description
# 2200-2299   Utilities                  100
# 3100-3399   Manufacturing             1293
# 5240-5249   Insurance                  487
# 8100-8399   Certain Services           533
# 8110-8139   Certain Services             7
# dtype: int64

# %% [markdown]
# ### From the dataframe, we obtain the NAICS Code and Description of the business categories having the least count of businesses.

# %% [markdown]
# ### However, it is better to focus attention on the industry categories which have been lagging behind in the recent years. That way, we can focus attention and resources in upbringing businesses in those categories.

# %%
# Extract year from Business Start Date to categorize businesses in less popular indusries by years

from datetime import datetime as dt

df_less_pop.loc[:,"Start_Date"] = pd.to_datetime(df_less_pop.loc[:,"Business Start Date"], format= "%m/%d/%Y")
df_less_pop.loc[:,"Start_Date"].dt.year.unique()
# Out:
# C:\Users\Home\Anaconda3\lib\site-packages\pandas\core\indexing.py:337: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\Home\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# array([2002, 1968, 1989, 1996, 2005, 1969, 1970, 1971, 1972, 1973, 1975,
#        2013, 1976, 1990, 2009, 1977, 1978, 1979, 1981, 1982, 1997, 1983,
#        1984, 2004, 1985, 2001, 1986, 1987, 1988, 1994, 1993, 2000, 1998,
#        1991, 1992, 2011, 1995, 2008, 1947, 2003, 1999, 2012, 2010, 2007,
#        2006, 2014, 1956, 1955, 1965, 1974, 2015, 2017, 2016, 1980, 2020], dtype=int64)

# %% [markdown]
# ### We take the recent 6 years into consideration to head in a direction of bringing those industries into the competitive market which have fallen behind in the age of technology.

# %%
# Filter the businesses during the recent years by year > 2012

df_less_pop_year = df_less_pop[df_less_pop["Start_Date"].dt.year > 2012]
df_less_pop_year.groupby(["NAICS Code","NAICS Code Description"]).size().reset_index().rename(columns = {0 : 'Count'})
# Out:
#   NAICS Code NAICS Code Description  Count
# 0  2200-2299              Utilities     34
# 1  3100-3399          Manufacturing    489
# 2  5240-5249              Insurance    149
# 3  8100-8399       Certain Services    305
# 4  8110-8139       Certain Services      3

# %% [markdown]
# ### In conclusion, we find out that Utilities, Insurance, Certain Services, Manufacturing industries are still lagging behind in the modern age since they were first categorized. The government needs to divert its attention and funding into improving businesses in these sectors

# %% [markdown]
# ### The insurance plans do not cover a major part of the basic portion of the healthcare. Improving this would lead to people buying more affordable and cost covering healthcare plans which in the end would lead to higher revenues for the industry.

# %% [markdown]
# ###  Number of quality products being made available to customers is not significantly high. Increasing the number and quality of businesses would lead to more competition resulting in growth of industry and people obtaining products with higher satisfaction.
# ### This would lead to less wastage of resources also and contribute positively to earth's environment.

# %%
# Names of businesses who need support in order to grow and compete with newly emerging businesses
names = list(df_less_pop["Ownership Name"].values)
names = set(names)
names
# Out:
# {'Lee Johnny & Katherine',
#  'J & W Sewing Inc',
#  'Chic Incorporation',
#  'Western Edition Skateboards',
#  'Spice Mama, Llc',
#  'Better Bakeries Inc.',
#  'Anzalone Jonathan',
#  'Caitlin Freeman/beth Miles',
#  'Forerunners Rest Equip Co',
#  'Agnello Mark',
#  'Olive Media Inc',
#  'C & W Fashion Inc',
#  'Welsh Michael',
#  'Test Phil 17rg',
#  'Romeo Lopez Villalobos',
#  'Sullivan John D',
#  'Pineda Rosa E',
#  'Mclin Gowan O',
#  'Dark Nacre Atelier Llc',
#  'Hostetter Asako',
#  'Big Heart Pet Brands',
#  'Ultimate Cookie Co Inc',
#  'Cchi Insurance Services',
#  'Down Etc Llc',
#  'William Joseph Weisman',
#  'Weber Edmund R',
#  'D. Danz & Sons Inc',
#  'Hayashi Haruhiko',
#  'Cohn Trudy Survivors Turst',
#  'Phommaa Britiany',
#  'Hdc Wine Company Llc',
#  'Arrowhead Graphix, Inc.',
#  'Li Liu Mei',
#  'Vuong Paul C',
#  'Clement Bruce E',
#  'Denning Cabinetry',
#  'Die & Tool Products Co Inc',
#  'The Dogleg Inc',
#  'Kamimoto Michael A',
#  'Chiu Anna And Santillo Valerie',
#  'Malatesta & Company Inc',
#  'Isu Group Inc',
#  'Chen Jenny',
#  'Molekule Inc',
#  'Lai Chang Thelma',
#  'Triple Aught Design Llc',
#  'Palmer Group Llc',
#  'Benedito L/benedito J',
#  'Cen Yan Ci',
#  'Tako Studios Llc',
#  'Lit Motors Corporation',
#  'Wei Donna',
#  'Voleurs De Vin Llc',
#  'Sutro Lab Llc',
#  'Runchan Lu',
#  'Spencer Philip Rodgers',
#  'Central Concrete Supply Co Inc',
#  'Foxtail Hill Windows & Doors',
#  'California Shower Door Corp',
#  'Southern California Edison Co',
#  'Kuang Jin Jun',
#  'Chocolate Holdings Inc',
#  'Gorham John M',
#  'Bushakan Llc',
#  'Broughton Woodworking Inc',
#  "Laura O'malley",
#  'Ipside Innovation Inc.',
#  'Ophthalmic Mutual Insurance Co',
#  'Ding Chang Feng',
#  'John Gardiner Automotive Inc',
#  'Lyz Inc',
#  'Tong Samuel Y W',
#  'Plut Insurance Agency Inc',
#  'Pattern Energy Group Lp',
#  'Joseph N. Wineroth,inc.',
#  'Maragoulas Phillip J',
#  'Chris Robertson',
#  'Raffetto Victoria',
#  'Kung David & Lau Sanford',
#  'Paccrest Insurance Associates',
#  'New Universal Kitchen Equip.mf',
#  'Dereck Suguitan',
#  'Fleeta Material Things Inc',
#  'Nureyev Tiersa E',
#  'Archer Stephen',
#  'Chachingly Llc',
#  'Landry Thomas K',
#  'Turning Point Coffee Llc',
#  'Truong Johnathon K',
#  'Michler Kirsten A',
#  'Marlen Hazel Hand Engraving',
#  'Black Hammer Brewing Llc',
#  'Intermodal Structures Llc',
#  'Biddle Shaw Insurance Services',
#  'Cnry Inc',
#  'Filmless, Llc',
#  'Meghan Harris Consulting Llc',
#  'Marin Jose G',
#  'Jw Insurance Services Inc',
#  'Royal Angela R',
#  'Gorham Holding & Capital Co',
#  'Trans Ceramica Ltd',
#  'Hollister Inc',
#  'Lee & Lee Garments Inc',
#  'Banks Mika M',
#  'Haworth Inc',
#  'Kenu Inc',
#  'Golden Mustang Energy Llc',
#  'Coronel Franklin',
#  'Mitzu Printing Inc',
#  'Super King Food Products Inc',
#  'United Healthcare Svcs Inc',
#  'Dias Ashley',
#  'Lennick Jennie',
#  '10x Genomics',
#  'Prof Tech Security Serv, Inc.',
#  'Nicoletta Sophia Celine',
#  'Personal Tex Inc',
#  'Sure Building Products Inc',
#  'Kings Asian Gourmet Inc',
#  'Lyman Chao Insurance Agency Llc',
#  'Lewallen Sharon M',
#  'Integrated Digital Media',
#  'Eko Arc Llc',
#  'Krivens Partners Llc',
#  "Vegetable Products From Dr Cowan's Garden Inc",
#  'Mansfield La Sonia',
#  'Dqe Associates Llc',
#  'Kim Andrew',
#  'Molly Bloom',
#  'Blackstone Amy G',
#  'Flores Prieto Maria Eugenia',
#  'Gorham Carl Michael & Karen',
#  'Lovegen Studio',
#  'Vansark',
#  'My Little Sunshine Chldcre Llc',
#  'Boyd Dejon & Wilson Savannah',
#  'Chacon Jairo G',
#  'Mel Elliott',
#  'Herrera Maria Carolina',
#  'Glikshtern Peter',
#  'Solar Energy Insurance Services, Inc.',
#  'Bellywell Kitchen Llc',
#  'Key Jewelry',
#  '3m Company',
#  'Laing Richard',
#  'Prestige Milling Inc',
#  'Martinez Hernandez Pablo',
#  'Dmcg Inc',
#  'Rageon, Inc.',
#  'Choy Nancy',
#  'Petrakis Danae & Petrakis Kristina',
#  'Delbonta Martin D Inc',
#  'Rossi Luis M',
#  'Pon Kwok-Yee',
#  'Skyblue Sewing Mfg Inc',
#  'Ma Chun Chuen',
#  'Ferruccio Joseph',
#  'Elektra Steel Llc',
#  'Buffalo,ray V. / Moses Anne',
#  'White William D',
#  'Etonway Financial And Insurance Services',
#  'Gigabyte Graphics Inc',
#  'Spark',
#  'Umalon Surfboards Llc',
#  'Goode Nyla',
#  'Speakeasy Ales & Lagers Inc',
#  'St Clair Roberts',
#  'Nomiku Inc',
#  'Fangonilo Edmund O',
#  "Andrea's Natural Marble Stone",
#  'Enzo Sherman Group Llc',
#  'Allstar Financial Group Inc',
#  'San Francisco Health Authority',
#  'S & A Horn Limited',
#  'Made In Mendoza, Llc',
#  'Kim Carolyn S',
#  'Corey Egan, Llc',
#  'Glaser Designs Inc',
#  'Manichon Virginie',
#  'Sequoia Sake Company Llc',
#  'The Window And Door Shop Inc',
#  'Little Quiapo Bakeshop Llc',
#  'Benjamin Moore & Co',
#  'B & Y Sewing Inc',
#  'The Hanover Insurance Company',
#  'Equity Risk Partners',
#  'Kim Jason',
#  'Zuli Inc',
#  'Xie Flora',
#  'Garcia Rafael',
#  'Dubreuil Olivia Lauren',
#  'Kenwood Cabinetry Inc',
#  'Dcsm Iv',
#  'Brahian Martinez',
#  'Dupaix Mark A',
#  'Jc Garment Inc',
#  'Saulsbury Ryan',
#  'Broad Spectrum Insur Srvcs Inc',
#  'Synergy Apparel Llc',
#  'Nway America Llc',
#  'Fong Kee Tofu Co Inc',
#  'Zest Llc',
#  'Li Jessie',
#  'Mitchell James',
#  'Porter Jordan',
#  'Kixel Inc',
#  'C&c Esthetics Co.',
#  'Sprint United Management Co',
#  'Stars Model Management Inc',
#  'Integro Usa Inc',
#  'Airbnb Samara, Inc.',
#  'Suica Karinna',
#  'Mazter Vip',
#  'Steelcase Inc',
#  'Smith Health, Inc.',
#  'Perez Luis A',
#  'Vanity Garment Sewing Fcty In',
#  'Sf Alternator Starter Exch Inc',
#  'M2m Ndt Inc',
#  'Onekind.25 Llc',
#  'Matthews Art Framing Inc',
#  'Oak River Insurance Company',
#  'Gould Geoffrey',
#  'Avery Dennison Retail Informat',
#  'Hooten Eric T Sarna Carolyn J',
#  'Mare Mario/yoon Tae Ho',
#  'Sea Maid Manufacturing Inc',
#  'Mary Leon Rodriguez De Sanchez',
#  'Novelli Robert Paul',
#  'Jones Darryl',
#  'Song Han',
#  'Vegher John',
#  'Wong Melvin F',
#  'Kirribilla Llc',
#  'Dependable Letterpress Inc',
#  'New Desserts, Inc.',
#  'Bankard Scott M',
#  'Breachgate Llc',
#  'Britton Tracey/curtis Jeremie',
#  'Advanced Cleaning Systems Corp',
#  'Murphy Maryann C',
#  'West Coast Life Insurance Co',
#  'Ganbold Manduul',
#  'Boc Lucy',
#  'Easton Malloy Inc',
#  'Faze Apparel Llc',
#  'Tsang Eddie W',
#  'Montez Group Inc',
#  'Martinez Maria T',
#  'Backhoe Dispatch 24/7 Inc',
#  'Hernandez Ivette',
#  'Master Po Inc',
#  'Byer California',
#  'Eileen Glutzer',
#  'Bull Victor',
#  'Wild Card Roasters Llc',
#  'Uhc Of California',
#  'Haute Home Llc',
#  'Panelfold Inc',
#  'Dolphin Printing & Graphics Et',
#  'Scanlon Fang Inc',
#  'Tinuola O. Ademola M.d., Inc.',
#  'Villafuerte Lydia M',
#  'American Family Life Assurance Co Of Columbus',
#  'Raymond Williamson Insurance',
#  'Owen Jack A',
#  'Qia Sr San Francisco Operating Llc',
#  'Cuadra Philip',
#  'Klukowski Jeffery',
#  'Cisneros Luz',
#  'Xylander Brucius Von',
#  'Theresa Phelan',
#  'Mac Product Development Llc',
#  'Carezone Financial Services Llc',
#  'Viable Enterprise, Inc.',
#  'Mirza Arif',
#  "Rush & O'kane Inc",
#  'Outofworksuperheroes Llc',
#  'Salazar Anthony L',
#  'Sinto Gourmet Llc',
#  'Dte Energy Corporate Services Llc',
#  'Low Andrew R',
#  'Joel Banuelos, Cmt',
#  'R J Mcglennon Co Inc',
#  'Pourfard Nicholas',
#  'Abba Stone & Tile Inc',
#  'Wentif78 Inc',
#  'Carlos Kanjana & Christopher E',
#  'Dpcc Management',
#  'Zhou Denise Y',
#  'Fryer Kevin L',
#  'Yan Zhirong',
#  'Huang Wei Hsuan',
#  'Meric Susan & Musan',
#  'Renown Usa Llc',
#  'Situ Louis & Stella Y',
#  'Fante, Inc.',
#  'Aronson Laura A',
#  'St. John Knits, Inc.',
#  'Ehealth Insurance Services Inc',
#  'Ap Vin Llc',
#  'Pb Wines Inc',
#  'B And B Wine Company Llc',
#  'Thomma Friedemann',
#  'Barkology Inc',
#  'Hutten-Czapski Izabella',
#  'Rubin Richard & Andrea',
#  'Scheib Eric & Danette',
#  'Donald Denise',
#  'Dufficy John',
#  'Jenny Ning',
#  'Lilot Kim E',
#  'Handup Pbc',
#  'Pitney Bowes Management Svcs',
#  'Conen Gabriel M',
#  'Markel Service Incorporated',
#  'Rogers Theresa M',
#  'Montagnino Donald Scott',
#  'Wong Belinda',
#  'Nancy Donnelly',
#  'Darling-Delaware Co Inc',
#  'Harmonic Brewing Llc',
#  'Gohn Michelle D',
#  'Highland Technology Inc',
#  'Rose Garment Inc',
#  'Lightbend Inc',
#  'Prior Thomas',
#  'National Apparel Llc',
#  'Ferris Katia And Wilson Peter S',
#  'Somo Global Inc',
#  'Du Qing & Du Hui Yuan Li',
#  'Guzman Pedro',
#  'M Flower Garnent, Inc',
#  'Tyler Heschong',
#  'Bergere Gregory O',
#  'Chow Sylvia H',
#  'Lim Innovations',
#  'Svendsen Michael',
#  'Grogan Ann',
#  'Law Office Of Pazit Zohar',
#  'Y W Electrical Co Inc',
#  'So Albert S Logiudici John R',
#  'Colony Management Services Inc',
#  'Rathakar & Sons',
#  'Gov Kim',
#  'Fsic Insurance Agency Llc',
#  'Baca Brigid',
#  'Martin Dalila J',
#  'Azzedine Mechid',
#  'Johnston William Z',
#  'Atlas Screw Mach Prod Co Inc',
#  'Lenox Stained Glass',
#  'Xl Specialty Insurance Company',
#  'Connie L Kong & Aaron H Kong',
#  'Test Marissa',
#  'Chelsea Risk Mgmt & Ins Sv Inc',
#  'Wright Etsuko T',
#  'Jobe Stephen',
#  'Sensory Revolution Llc',
#  'Sylverline Llc',
#  'Technical Graphics Inc',
#  'Risk Placement Services Inc',
#  'Cayson Designs, Llc',
#  'Popular Table Llc',
#  'Crystal Ibc Llc',
#  'Espy Gregory',
#  'Li Fan Tang/lai Chan Siu Lin',
#  'Jkl Windows & Glass',
#  'Valerio Maria L',
#  'Lee Curtis',
#  'Son You Jin Sarah',
#  'Hogan Modern Llc',
#  'Hanoun Gabi J',
#  'Nelson Daniel',
#  'Barbanell Associates Inc',
#  'Munkanta Kachusha',
#  'New Rich World, Llc',
#  'Choy Terrance',
#  'La Adam & Ly Jennifer',
#  'Wo Chong Co Inc',
#  'New Century Custom Cabinets In',
#  'Westport Insurance Corp',
#  'Amazing Health Insurance',
#  'Gutkin Peter A',
#  'Gemmiti Model Art Corporation',
#  'Garcia Jose O',
#  'Byrne Neil P',
#  'Latticestix Inc',
#  'Dm Dawson Inc',
#  'Laurel Sprigg Inc',
#  "Paul's Hat Works Inc",
#  'Wong Jeffrey',
#  'Walsh Carter & Ass Ins Srv Llc',
#  'Webb Alan & Bradley Sarah',
#  'Genevaspot Productions Llc',
#  'Pedro Garcia',
#  'Delta Dental Of California',
#  'Amt Warranty Corp',
#  'Cascadian Fabrications Inc',
#  'Cal Insurance & Associates Inc',
#  'Tsang Shu-Hung',
#  'Dmax Imaging Llc',
#  'Sour Flour Corporation',
#  'Chow Kwan',
#  'De Raat Maia K',
#  'Praxair Distribution Inc',
#  'Lichtenberg, Rose Alexandra',
#  'Betterlys Organic Personal Care Products',
#  'Viacheslav Kalinchuk',
#  'Caroline Brede',
#  'Citi Peter',
#  'Supreme Ink Inc',
#  'Roozmerica Industries, Llc',
#  'Carlaccini Thomas A',
#  'Luong Susan',
#  'Htc Body Piercing Of California',
#  'Thingm Corporation',
#  'Kitagawa Eric',
#  'Centinel Agency Llc',
#  'Manuel Tara',
#  'Sardella Candice B',
#  "Campero's Inc",
#  'J.o. Supply',
#  'Moreno Andres',
#  'Martinez Marta L',
#  'Ten 250 Corporation',
#  'Robert Walter Lewerenz',
#  'Lu Joanna',
#  'Gilbert Rita Carolyn',
#  'Pay Ru Zhang',
#  'Juicero Inc',
#  'Ivankovitser Izabella',
#  'Campos David',
#  'Glory Care Life Inc',
#  'Doorglobe Inc',
#  'Ramirez Alfredo',
#  'Wright Neville V',
#  '1150 Howard Partners Lp',
#  'Camano Jorge C',
#  'Texas Instruments Incorporated',
#  'Rockhill Insurance Svcs Llc',
#  'Softonic Inc',
#  'Mimeo Labs Inc',
#  'Colloquy Llc',
#  'Axis Specialty Us Services Inc',
#  'Brunini Danielle',
#  'Rainbow Snack Company',
#  'Conley Mary E',
#  'Isobe Brian Y',
#  'Weight Watchers North Amer In',
#  'Pacific Brewing Laboratory Llc',
#  'Liu Haiying',
#  'Ottomotto Llc',
#  'Erna Press Llc',
#  'Visionary Electronics Inc',
#  'Kennedy Robert E Jr',
#  'Barebottle Brewing Co',
#  'Benge Fabrik',
#  'Raymond Chi Cheong Wong',
#  'Corcia Vito',
#  'Klein And Co',
#  'Mark One Lifestyle Inc',
#  'Aesynt Incorporated',
#  'Tucker & Marks Inc',
#  'Madrid James M',
#  'Exigis Llc',
#  'Palletechnology Inc.',
#  'States Title, Inc.',
#  'Driver',
#  '6sensorlabs Inc',
#  'Tsui Tak',
#  'Danielson Michael A',
#  'Roehrman Todd F',
#  'Sartor & Co Inc.',
#  'Panebianco Vincenzo',
#  'Vivas Banners & Signs Inc',
#  'Man Cardy H M',
#  'Bruhn Derek',
#  'Yan John M',
#  'Kinsa Inc',
#  'Rocereto Soojo & Thomas',
#  'Ng Jake S',
#  'Luk Ming',
#  'Momentum Machines Company',
#  'Littlemore Llc',
#  "D'aura Joseph O",
#  'Hunters Point Brewery Llc',
#  'Peaters Courtney',
#  'Lincoln Financial Advisors Cor',
#  'Glogoodz Llc',
#  'Liu Jing & Yang Xiufang',
#  'Ymcm',
#  'Guy Robert N',
#  'Alleghany Corporation',
#  'Finesse Holdings',
#  'Magdalena Eneva',
#  'Epps Edith M',
#  'Mann Derek J',
#  'P G Molinari & Sons Inc',
#  'Sustainable Health Solutions',
#  'Distillery No 209 Ltd Napa Ca',
#  'Sunfolding Inc',
#  'Reichenbach Astrid E',
#  'Go Mighty',
#  'Nathaniel Galipeau',
#  'Roemer Susan K',
#  'Fangzhou Liang',
#  'Regency Packaging Inc.',
#  'Laserlink International Inc',
#  'Barnett David S S',
#  'Onyx Insurance Company Inc',
#  'Houlihan Monica',
#  'Perlsweig Pesha',
#  'Green Graham C',
#  'Suh Young M',
#  'Kanna Group Llc',
#  'Flanagan Hammond William',
#  'Kim Laura J',
#  'Liu Zhi Chun',
#  'Won Tiffany',
#  'Impact Recruiting Llc',
#  'Yu Marilyn A',
#  'Miyamoto Keith I',
#  'Title Resource Group Llc',
#  'Stuermer Marcia R',
#  'Mike Mcfarling Ins Agency Llc',
#  'Beach Nikki',
#  'Merry Go Round Day Care Inc',
#  'Reedy Eric',
#  'Mclaughlin Bernard J',
#  'Lee Richard',
#  'Lee Zee',
#  'Santos Melissa Rose',
#  'Microaeth Corporation',
#  'Sporlan Valve Div Of Parker Ha',
#  'Mattel Sales Corp',
#  'Hutchinson Sara J',
#  'Ava Food Labs, Inc.',
#  'Tatcha Llc',
#  'Maskd',
#  'Jenson Richard A',
#  'Diane Harwood',
#  'Scarf Leis',
#  'Maria Violeta Isidro',
#  'African Arts Academy',
#  'Puglisi Fernando L',
#  'Classpass, Inc.',
#  'Eli Lilly & Company',
#  'Garcia Martha Luz',
#  'Marcarian Gordon M',
#  'Sarkissian Watche',
#  'Louie William',
#  'Fine Robert',
#  'Nguyen Nguyet Thi Anh',
#  'Bartels Luke A',
#  'Marsh Usa Inc',
#  'Foster Warren E',
#  'Leong Fook Yam',
#  'Magallanes John',
#  'Combos Glass Inc',
#  'Pena Mariano',
#  'Blaise Gary A',
#  'Lyf Financial Services Llc',
#  'Tuck Jennifer A',
#  'Garza Michael B',
#  'Tse David',
#  'Verizon Corporate Svcs Group',
#  '168 Fortune Cookie Inc',
#  'Top Typists',
#  'Michelle Chan',
#  'Brokers Sf',
#  'Long Dragon',
#  'Nataliya Tsvetkova',
#  'Yuemei Xie',
#  'Califashions Manufacturing Inc',
#  'Presler Alex & Olskiy Petr',
#  'Bonafide Insurance Group Inc',
#  'Fruitridge Printng & Litho Inc',
#  'Carlsson Christopher J',
#  'Dixon Phillip R',
#  'Eps Settlements Group Inc',
#  'Social Imprints Llc',
#  'Monmo Treats Llc',
#  'Basic West Insurance Agency',
#  'San Francisco Institute Beauty Lab, Inc.',
#  'Lewis Heredia',
#  'Niemier Jul',
#  'Fire Road Llc',
#  'Min Hwang & Kyung Hae',
#  'Precision Index Co Inc',
#  'Speak E Z',
#  'Ow-Wing Teresa & Pon Jon',
#  'Aetna Health Plans Of Ca Inc',
#  'State Compensation Insurance',
#  'Hills Kalani Tonie Marie',
#  'Leggett Henry S',
#  'Square Trade Inc',
#  'Gabereal Creations Llc',
#  'Walther Astrid & C Gardelle',
#  'Drip Drop Inc',
#  'Xiao Cheng Mei',
#  'Adamant Llc',
#  'Dori Ronnie P',
#  'Circa Of America, Llc',
#  'Esurance Inc',
#  'Pax Labs Inc',
#  'Toscanini Michael',
#  'Aleman Marcia',
#  'Gilt City Inc',
#  'The Orchid Salon Inc',
#  'Fong Bros Printing Inc',
#  'Thomas Miller (Sf) Inc',
#  'Li Hong Hai',
#  'Jbse, Llc',
#  'Cuevas Anthony',
#  'Cirecast Inc',
#  'Ishihara Corp (Usa)',
#  'Wu Wing-Fai',
#  'Thompson Alex',
#  'Mernolito Collado',
#  'Lai Tai T',
#  'The Nik-O-Lok Co',
#  'Chan Sau King',
#  'Ironshore Insurance Svcs Llc',
#  'Class Petra A',
#  'Love And Hummus Co Llc',
#  'Endert Roderick F',
#  'The Hartford Steam Boiler Inspection And Insurance Company',
#  'Woodson Vaughan K',
#  'Erdenetsetseg Yondon',
#  'Ng Angela',
#  'Boyon Elevator Technlgy Co Ltd',
#  'Dempsey Ryan W',
#  'Larot, Dion & Larot, Maricar',
#  'El Raigon Natural Beef',
#  'R Carrie Insurance Agency Inc',
#  'Chen Danyan',
#  'Western Textile & Mfg Inc',
#  'Edgewater Insurance Solutions Llc',
#  'Noma Us Inc',
#  'Marks Daniel',
#  'Insight Healthcare Pdts Rsh In',
#  'Yu Xiu Ping Li',
#  'Lee Irene',
#  'Ad Art Inc',
#  'Godar Justin Ross',
#  'Anello Rob K',
#  'Martin Brian M',
#  'Autodesk Inc',
#  'Plivo Inc',
#  'Local Brewing Co Llc',
#  'Becherini Paolo',
#  'Magellan Hrsc Inc',
#  'Seikwei Travel Inc',
#  'Osheka, Inc.',
#  'Macaire Muriel',
#  'Kirchner Dianne C',
#  'Arista Networks Inc',
#  'Bespoke Innovations Inc',
#  'Socius Insurance Services, Inc',
#  'Arioswaldo Alvarenga',
#  'Major League Orthopaedics Inc',
#  'Barbara Thleiji',
#  'Priority Architectural Graphics',
#  'Kong Aaron & Connie',
#  'Enwereuzo Michael Anthony',
#  'Worldwide Facilities Inc',
#  'Venetian Natural Marble Co In',
#  'Yuhin Wahjudi',
#  'Niba Home Rugs Inc',
#  'Pageantrocks Llc',
#  'Da Rosa Simone',
#  'Black Pants Inc',
#  'Zlatev Konstantin K',
#  'Ortiz Hector A',
#  'West Coast Industries',
#  'Fog City Dog Lodge, Inc.',
#  'W T Sewing Inc',
#  'Gsfca Llc',
#  'Kong Yin F',
#  'Glass George Ben',
#  'Cankun He',
#  'Monkeyfox Design Llc',
#  'Cruz Henry G',
#  'Gutfreund Minette T',
#  'Old Republic Natl Title Ins Co',
#  'Benefitter Insurance Solutions',
#  'Ladue Ruth Anne',
#  'Highsmith Grace Soonchan',
#  'Matt Hutchinson',
#  'Siwakoti Sangita & Khanal Renuka',
#  'Christina Smith',
#  'Anthony Jackson',
#  'Agricola',
#  'Lombardo Louis',
#  'Cardoon Llc',
#  'Liu Eric',
#  'Ortega Gloria E',
#  'Carella Len M',
#  '777 Worldwide Llc',
#  'California American Water',
#  'Test August 1 2016',
#  'Crunch Culture, Inc.',
#  'Amblard Beatrice A',
#  'Save The Redwoods League',
#  'Rubie Mia L Ramos Richard A',
#  'Pacific Shaving Company Inc',
#  'Anderson Carl N',
#  'Tat Kim H',
#  'Tourance Inc',
#  'Marilia Poggiali',
#  'Severns Casey P',
#  'Yu Lara',
#  'Imported Motor Service Inc',
#  'Transamerica Life Insurance Co',
#  "Kika's Treats Llc",
#  'Ocean Beach Sportswear Inc',
#  'Mitchell International Inc',
#  'Dalat Llc',
#  'Diaz Edurne',
#  'Gallardo Sergio D',
#  'Porto Llc',
#  'Amwins Ins Brokerage Of Ca Llc',
#  'Hushtech Inc',
#  'Hull Beverly A',
#  'Budget Signs Inc',
#  'Aep Industries Inc',
#  'World Affairs Council Of Northern California',
#  'Polnar Roman',
#  'Board Marine Underwriters Sf',
#  'Pci Services Inc',
#  'Pattern Energy Group Inc',
#  'Reed Carol A',
#  'Karp Kenneth M',
#  'Symmetric Labs, Inc.',
#  'Mcgrath Molly E',
#  'Killpack Grace',
#  'First Samoan Con Unit Ch Of Ch',
#  'Ramos Jhony',
#  'Rock N Roll Relics',
#  'Barkann Susan G',
#  'Bleu Corporation',
#  'Xyz Graphics Inc',
#  'Ohio Inc',
#  'Marinas Aida E',
#  'Tadashi Filters Llc',
#  'Garcia Gerardo',
#  'Jiang Watson L K',
#  'Revelli Mary E',
#  'Contreras Robert',
#  'Ermico Enterprises Inc',
#  'Cjc Management Group Inc',
#  'World Apparel Llc',
#  'Ryan Specialty Group Llc',
#  'Zhao Li Hua',
#  'Gonzales Eric S',
#  'Jennifer R Mcpike',
#  'Rrti Inc',
#  'Aiken Akala',
#  'Physicians Reimbursement Fund',
#  'Invuity Inc',
#  'Donnelley R R & Sons Co',
#  'Webpass Inc',
#  'Insignia Inc',
#  'Alkordy Marwa',
#  'Deluco Pamela R',
#  'Raven Fitness',
#  'Nago Llc',
#  'Le Boulch Soizig',
#  'Vicente Paulo De Matos',
#  'Benett John',
#  'Wan Cheng Mo',
#  'Stevens Kumiko E',
#  'Parlor Llc',
#  'Naomi Nim Insurance Agency, Llc',
#  'Yip Joe',
#  'Yee James',
#  'Liz Palacios Designs Ltd',
#  'S & D 1232 Llc',
#  'Test - Acct Update 1',
#  'Advanced Digital Printing Lab',
#  'Beltran Juan Carlos',
#  'Solis Juan',
#  'Moellering Anne E',
#  'Barry Gnekow & Associates Llc',
#  'Kim Sun W',
#  'Arnold & Egan Mfg Co',
#  'Abd Insurance & Financial Serv',
#  'Natalie Pan',
#  'Mcinerney Owen',
#  'Webpass Telecommunications Llc',
#  'United Behavioral Health',
#  'Vilar Serena J',
#  'Practo Inc.',
#  'Ireland Joanne',
#  'Level 3 Communications Llc',
#  'Random Technologies Llc',
#  'Plantikow Timothy D',
#  'Villalpando Jr Hermenejildo',
#  'Treehouse Craft Distillery Llc',
#  'Chaves Francisco Leonardo A',
#  'Humimotors Llc',
#  'Edward Wedge',
#  'Marsh & Mclennan Agency Llc',
#  'Derek And Constance Lee Corp',
#  'Sanchez And Sons Llc',
#  'Yen Yen Dieu',
#  'Mcgary Edwin',
#  'Bryan Schepp',
#  'Kyle Mccrocklin',
#  'Thurston Charles M',
#  'X/open Company Limited',
#  'Najla Yoon',
#  'Franco Sara',
#  'Race Telecommunications, Inc',
#  'Voravong Sing',
#  'Tempo Automation, Inc.',
#  'Essential Formulations Llc',
#  'Innovant, Inc.',
#  'Buie Alpha J',
#  'Raju Uma D & Vimal K',
#  'New Pelvic Pain Technologies Inc',
#  'Cibc Insurance Services, Llc',
#  'Arbor Pharmaceuticals Sales Llc',
#  'Als Complete Welding Service',
#  'Cemex Inc',
#  'Velasquez John',
#  'Yeti Technologies Llc',
#  'Immucor Inc',
#  'Holbert Deneice M',
#  'Elwell Adrian J',
#  'Bay Health Ins Agency Inc',
#  'The Aesthetic Union Llc',
#  'Unhassobiscay / Lair',
#  'Rubio Jr Cesar A',
#  "Heron's Head Productions",
#  'Wang Ins Agency Inc',
#  'Dan Dugan Sound Design Inc',
#  'Hayman Consulting Llc',
#  'Fast Filings, Inc',
#  'Laseraway Medical Group',
#  'Solutions That Benefit Inc',
#  '8bithiphop',
#  'Calltower Inc',
#  'M Morelli Dsgn & Fabrication',
#  'Anchor Brewing Company Llc',
#  'Western Steel & Wire Inc',
#  'Mulholland Connlaoth S',
#  'Northrop Grumman Systems Corp.',
#  'Geozoning Inc',
#  'Binding Services Corp',
#  'Antonio-Hernandez Esteban',
#  'Hippo Treats Inc',
#  'Yamstreet Llc',
#  "Gao's Cabinet Inc",
#  'Ziddl, Inc.',
#  'Reyes Ricardo R',
#  'Herbert J Luke',
#  'Morthole Karl R',
#  'Persio Andrew F',
#  'Noir Lash Lounge',
#  'Jon Stevens',
#  'Ngai Tony Wing Chi',
#  'Reina Jaclyn',
#  'Wehlitz Hilary A',
#  'Atelier Des Modistes Inc',
#  'Double Rainbow Ice Cream Inc',
#  'Gusman Sandra',
#  'Lazaro Jose Luis',
#  'Lee Min',
#  'Seriforge Inc',
#  'Mpower Communications Corp',
#  'Interremedy Insurance Svcs Llc',
#  "L'amourette Chocolat Llc",
#  'Blackburn Ria',
#  'Variety Club Of No. Ca',
#  'Sanjeev Rai',
#  'Priscilla Vargas',
#  'Linh Ngoc Tu 2006 Trust',
#  'Endurance Services Ltd',
#  'Northern Cal Equipment Corp.',
#  'Advanced Technical Sewing Inc',
#  'Segelken Lance W',
#  'Brewer Benjamin D',
#  'Industrial Metal Products Inc',
#  'Gonzales Sabino T',
#  'Guan Zhe Dalina',
#  'Zimmerman Sharon N',
#  'Logvinova Lyudmyla',
#  'Transensys Llc',
#  'Dvd Copycat',
#  'Runsheng Chen',
#  'Ergonomic Dental Tech Inc',
#  'Gordon Adam R',
#  'Senn Brieanne',
#  'Witherspoon Christine V',
#  'Zebra Awning Co Inc',
#  'North East Exchange Team S F',
#  'Macktinger Jerry',
#  'Miller Ben',
#  'Allen S Feder & Co Inc',
#  'Front Row Builders Inc',
#  'Brown Mieasha',
#  'Youngs Custon Cabinet, Inc',
#  'Wholesale Trading Insurance Services Llc',
#  'Fresh Air Energy 1 Llc',
#  'First Spice Mixing Co Inc',
#  'Health-Chem Inc',
#  'Blum Andrea S',
#  'The San Francisco Mead Co Llc',
#  'Little Green Bee',
#  'Shopfloor Design Llc',
#  'Jb Woven Labels Co Usa Inc',
#  "O'hara William",
#  'Mattel Hq Inc',
#  'Sarah Malim Jewelry',
#  'Contador, Inc.',
#  'Pseudo Studio Llc',
#  'Contra Costa Radiator Inc',
#  'Tempest + Bentley Llc',
#  'Basil Racuk Llc',
#  'Swett & Crawford',
#  'Hoang Thuong N/nguyen Anh',
#  'Fetterman Sophita',
#  'Corvera Francisco',
#  'Lacampagne Emile Jean',
#  'Siegel Lauren M',
#  'Esco Foods',
#  'Cooper & Mccloskey Inc',
#  'Cali Rice Valley',
#  'Abrasha Staszewski',
#  'Intrinsic Devices Inc.',
#  'Marinovich Erik',
#  'Ocean International Travel Inc',
#  'Limos Jasmin A',
#  'Noson, Inc.',
#  'College & Retirement Planning',
#  'Robinson Scott J',
#  'S & T 1438 Enterprises Llc',
#  'Lockton Management Llc',
#  'Lev Probiotics Inc',
#  'Green Growth',
#  'Lair Jean Claude',
#  'Trueanthem Corporation',
#  'Maru Cycling Llc',
#  'Castillo Ali',
#  'Tabios Horlino M',
#  'Maguire Inc',
#  'Frankinc Inc',
#  'Lunsford Design Inc',
#  'Gantri Inc',
#  'The Rabbit Hole Theater Company Llc',
#  'Laverne Kelsey E',
#  'Munich Reinsurance America Inc',
#  'Weichel Kenneth',
#  'Beazley Insurance Services',
#  'Vasquez Luis Enrique',
#  'Zetaohm Llc',
#  'Jan B Hannah Insurance Agency',
#  'Coleman Arthur',
#  'Akerley Farm Llc',
#  'Julia Canright',
#  'Joseph Bruno Sheetmetal Co.inc',
#  'Embroker Inc',
#  'Nanocore Technologies',
#  'First Pacific Surety & Ins',
#  'Powell Bruce T',
#  'Lin Whitney Hui',
#  'Ssl Mda Holdings Inc.',
#  'Ayda Technologies Inc',
#  'Hamama, Inc.',
#  'Leland Lam',
#  'West Coast Garment Mfg Inc',
#  'Green Susan',
#  'Ng Philip',
#  'Evans Killean',
#  'Zhen Xiao Qiong',
#  'Tom Huynh',
#  'Montoya Jose D',
#  'Crave Innovations Inc',
#  'Kinninger Ninoska',
#  'Smashing Grapes Llc',
#  'Iqlink Technology, Inc',
#  'Potrero Depot Cleaning Inc',
#  'Woon Thomas L',
#  'Hollander Miklos',
#  'Orlando Perez',
#  'Dark Garden Unique Corsetry',
#  'Steinbach Kathryn A',
#  'New North American Food Manufacturing (Usa) Inc',
#  'Custom Silicone Fabr Of Sf Inc',
#  'Hr Bay Area Llc',
#  'Vashno Inc',
#  'Scott Whittemore Insurance Ser',
#  'Bolich David & Beatriz',
#  'Plethora Corporation',
#  'Kwong Anthony',
#  'Solar Turbines Incorp',
#  'Tw Telecom Of California, Lp',
#  ...}

# %% [markdown]
# ### The above list contains the businesses as per the 4 categories  i.e. Utilities, Insurance, Certain Services and  Manufacturing which need the tax break so that less investment is to be made by then and are encouraged to set up shop in San Francisco.

# %% [markdown]
# # Q3

# %% [markdown]
# ## What are the different types of industries that have emerged in San Francsico over the years?

# %% [markdown]
# ### We first identify the businesses which have come up just in San Francisco and then see the number of businesses which have come up in each year.

# %%
# First filter San Francisco 

business_sf = sf_business_dataset.loc[sf_business_dataset["Source Zipcode"].isin(zip_codes_sf["zip"]),:]
business_sf.shape
# Out:
# (168716, 26)

# %% [markdown]
# ### To achieve the objective, we get the business start date and find out the most last and the most recent year in which businesses have sprung up. We can check industry wise the starting year and ending year along with the count of businesses industry wise to determine the popularity based on quantity of businesses.

# %%
# Change the Date format 
# Create a new column  in business_sf dataset

from datetime import datetime as dt

business_sf["Start_Date"] = pd.to_datetime(business_sf["Business Start Date"], format= "%m/%d/%Y")
business_sf["Start_Date"].dt.year.sort_values().unique()
# Out:
# C:\Users\Home\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# array([1849, 1870, 1891, 1895, 1896, 1897, 1932, 1941, 1942, 1943, 1945,
#        1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956,
#        1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967,
#        1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978,
#        1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#        1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2020, 2021, 2024, 2027, 2029], dtype=int64)

# %%
# Calculate number of businesses starting each year listed in the dataset

business_sf.groupby(business_sf['Start_Date'].dt.year).size()
# Out:
# Start_Date
# 1849        1
# 1870        1
# 1891        1
# 1895        1
# 1896        1
# 1897        1
# 1932        1
# 1941        4
# 1942        2
# 1943        1
# 1945        4
# 1946       11
# 1947        7
# 1948        5
# 1949        8
# 1950        6
# 1951       10
# 1952        5
# 1953        8
# 1954        8
# 1955       10
# 1956        7
# 1957       12
# 1958       12
# 1959       11
# 1960        2
# 1961       11
# 1962        6
# 1963       10
# 1964       15
#         ...
# 1993     1413
# 1994     1590
# 1995     1837
# 1996     2230
# 1997     2277
# 1998     2523
# 1999     2800
# 2000     2818
# 2001     2838
# 2002     3359
# 2003     3837
# 2004     4404
# 2005     4795
# 2006     5406
# 2007     9271
# 2008     5934
# 2009     6136
# 2010     7341
# 2011     9213
# 2012    10223
# 2013    11650
# 2014    13824
# 2015    12773
# 2016    14915
# 2017     4530
# 2020        1
# 2021        3
# 2024        1
# 2027        1
# 2029        1
# Length: 88, dtype: int64

# %% [markdown]
# ### Below listed are the count of total businesses according to each category along with the starting year and ending/current year of each business

# %%
# Determining count of total businesses in San Francisco over the years based on industry

maxdate = pd.DataFrame(business_sf.groupby(['NAICS Code','NAICS Code Description'])['Start_Date'].max().reset_index())
mindate = pd.DataFrame(business_sf.groupby(['NAICS Code','NAICS Code Description'])['Start_Date'].min().reset_index())

merge_mxmn = pd.merge(maxdate,mindate, on=['NAICS Code','NAICS Code Description']).rename(columns = {'Start_Date_x': 'maxdate','Start_Date_y':'mindate'})
total_business = pd.DataFrame(business_sf['NAICS Code'].value_counts().reset_index()).rename(columns = {'NAICS Code':'count','index':'NAICS Code'})
total_business = pd.merge(merge_mxmn,total_business,on = 'NAICS Code')[['NAICS Code', 'NAICS Code Description','maxdate','mindate','count']]
new_industry.sort_values(['count'])

total_business["max_year"] = total_business["maxdate"].dt.year
total_business["min_year"] = total_business["mindate"].dt.year

total_business.drop(['maxdate','mindate'],axis=1, inplace=True)

total_business.sort_values(['count'])
total_business
# Out:
#    NAICS Code                            NAICS Code Description  count  \
# 0   2200-2299                                         Utilities    105
# 1   2300-2399                                      Construction   5262
# 2   3100-3399                                     Manufacturing   1380
# 3   4200-4299                                   Wholesale Trade   2657
# 4   4400-4599                                      Retail Trade   9429
# 5   4800-4999                    Transportation and Warehousing   8131
# 6   5100-5199                                       Information   2713
# 7   5210-5239                                Financial Services   3180
# 8   5240-5249                                         Insurance    529
# 9   5300-5399       Real Estate and Rental and Leasing Services  19801
# 10  5400-5499  Professional, Scientific, and Technical Services  16800
# 11  5600-5699               Administrative and Support Services   2490
# 12  6100-6299             Private Education and Health Services   5738
# 13  7100-7199               Arts, Entertainment, and Recreation   5222
# 14  7210-7219                                   Accommodations    3780
# 15  7220-7229                                     Food Services   7900
# 16  8100-8399                                  Certain Services    684
# 17  8110-8139                                  Certain Services     74
#
#     max_year  min_year
# 0       2017      1965
# 1       2017      1968
# 2       2017      1957
# 3       2017      1968
# 4       2017      1958
# 5       2017      1949
# 6       2017      1849
# 7       2017      1956
# 8       2017      1955
# 9       2017      1945
# 10      2029      1953
# 11      2017      1897
# 12      2024      1948
# 13      2017      1947
# 14      2021      1932
# 15      2017      1960
# 16      2020      1947
# 17      2015      1995

# %% [markdown]
# ### Below listed are the count of active businesses according to each category along with the starting year and ending/current year of each business

# %%
# Determining count of active businesses in San Francisco over the years based on industry

max_date = pd.DataFrame(business_sf.groupby(['NAICS Code','NAICS Code Description'])['Start_Date'].max().reset_index())
min_date = pd.DataFrame(business_sf.groupby(['NAICS Code','NAICS Code Description'])['Start_Date'].min().reset_index())

merge_mxmn = pd.merge(maxdate,mindate, on=['NAICS Code','NAICS Code Description']).rename(columns = {'Start_Date_x': 'max_date','Start_Date_y':'min_date'})
active_business_year= pd.DataFrame(active_business_sf['NAICS Code'].value_counts().reset_index()).rename(columns = {'NAICS Code':'count','index':'NAICS Code'})
active_business_year = pd.merge(merge_mxmn,active_business_year,on = 'NAICS Code')[['NAICS Code', 'NAICS Code Description','max_date','min_date','count']]
active_business_year.sort_values(['count'])

active_business_year["max_year"] = active_business_year["max_date"].dt.year
active_business_year["min_year"] = active_business_year["min_date"].dt.year

active_business_year.drop(['max_date','min_date'],axis=1, inplace=True)

active_business_year.sort_values(['count'])
active_business_year
# Out:
#    NAICS Code                            NAICS Code Description  count  \
# 0   2200-2299                                         Utilities    100
# 1   2300-2399                                      Construction   5039
# 2   3100-3399                                     Manufacturing   1293
# 3   4200-4299                                   Wholesale Trade   2486
# 4   4400-4599                                      Retail Trade   8753
# 5   4800-4999                    Transportation and Warehousing   7014
# 6   5100-5199                                       Information   2501
# 7   5210-5239                                Financial Services   2945
# 8   5240-5249                                         Insurance    487
# 9   5300-5399       Real Estate and Rental and Leasing Services  18937
# 10  5400-5499  Professional, Scientific, and Technical Services  15689
# 11  5600-5699               Administrative and Support Services   2353
# 12  6100-6299             Private Education and Health Services   5467
# 13  7100-7199               Arts, Entertainment, and Recreation   4919
# 14  7210-7219                                   Accommodations    3352
# 15  7220-7229                                     Food Services   7197
# 16  8100-8399                                  Certain Services    533
# 17  8110-8139                                  Certain Services      7
#
#     max_year  min_year
# 0       2017      1965
# 1       2017      1968
# 2       2017      1957
# 3       2017      1968
# 4       2017      1958
# 5       2017      1949
# 6       2017      1849
# 7       2017      1956
# 8       2017      1955
# 9       2017      1945
# 10      2029      1953
# 11      2017      1897
# 12      2024      1948
# 13      2017      1947
# 14      2021      1932
# 15      2017      1960
# 16      2020      1947
# 17      2015      1995

# %% [markdown]
# ### We take into consideration the list of active businesses more as they contribute to the revenue and economy of the country.
# ### We conclude that  businesses in the field of Information, Administrative and Support Services, Transportation and Warehousing were in greater numbers before 1950

# %% [markdown]
# ### After the 1950 decade, industries such as Real Estate and Rental and Leasing Services, Professional, Scientific, and Technical Services along with wholesale trade came to light.

# %%
# To check whether both(all and active) business dataesets are in the same shape or not
total_business.shape, active_business_year.shape
# Out:
# ((18, 5), (18, 5))

# %% [markdown]
# ### We already have the numbers for active businesses and total businesses.

# %%
# Generate a ratio to see the proportion of business have remained active throughout the years since the beginning of the 
# industry by dividding count of active businesses to that of total businesses in San Francisco

total_business["prop_active"] = active_business_year['count']/total_business['count']

# %%
# Count - contains total business till now 
# prop_active contains proportion of the total business that are still active sorted by starting year of particular industry
    
pd.set_option('precision',4)
total_business = total_business.sort_values(['min_year'])
total_business.loc[:,total_business.columns !='max_year']
# Out:
#    NAICS Code                            NAICS Code Description  count  \
# 6   5100-5199                                       Information   2713
# 11  5600-5699               Administrative and Support Services   2490
# 14  7210-7219                                   Accommodations    3780
# 9   5300-5399       Real Estate and Rental and Leasing Services  19801
# 16  8100-8399                                  Certain Services    684
# 13  7100-7199               Arts, Entertainment, and Recreation   5222
# 12  6100-6299             Private Education and Health Services   5738
# 5   4800-4999                    Transportation and Warehousing   8131
# 10  5400-5499  Professional, Scientific, and Technical Services  16800
# 8   5240-5249                                         Insurance    529
# 7   5210-5239                                Financial Services   3180
# 2   3100-3399                                     Manufacturing   1380
# 4   4400-4599                                      Retail Trade   9429
# 15  7220-7229                                     Food Services   7900
# 0   2200-2299                                         Utilities    105
# 1   2300-2399                                      Construction   5262
# 3   4200-4299                                   Wholesale Trade   2657
# 17  8110-8139                                  Certain Services     74
#
#     min_year  prop_active
# 6       1849       0.9219
# 11      1897       0.9450
# 14      1932       0.8868
# 9       1945       0.9564
# 16      1947       0.7792
# 13      1947       0.9420
# 12      1948       0.9528
# 5       1949       0.8626
# 10      1953       0.9339
# 8       1955       0.9206
# 7       1956       0.9261
# 2       1957       0.9370
# 4       1958       0.9283
# 15      1960       0.9110
# 0       1965       0.9524
# 1       1968       0.9576
# 3       1968       0.9356
# 17      1995       0.0946

# %% [markdown]
# ### From the ratio, we can conclude that Certain services with index number 17 has seen no new business come up in recent years (since its active ratio is less than 0.09).
# ### Certain Services, Accommodations, Transportation and Warehousing industries ( with  a ratio of less than 0.9) have also seen less emergence over the years.

# %% [markdown]
# ### Rest of the industries have an active proportion of emerging buinsesses since their ration is above 0.9 and we can use these values as approximations.

# %% [markdown]
# # Q4 What other conclusions and interesting stories can be drawn from the data?

# %% [markdown]
# ## We have analyzed only minor portion of data and drawn out some conclusions from it, but there are a lot many attributes that can mined for information and analyzed for general deductions and predictions.

# %% [markdown]
# ###  We can perform text mining to see which companies/businesses (industry can also be included) are setting up and expanding in which streets ( location also) of San Francisco. This would help us gather their preferences and decipher as to why they prefer those locations (maybe because of rent prices, utilities, closely located to public transportation, etc.)

# %% [markdown]
# ### Determine the parent ownerships(from ownership name) of each business and see which parent owner is investing in which business (more broadly in which industry) for investments.One can generate a decision tree based on the results derived to see as to why a particular company is interested to invest in specific ( can be industry based also) businesses.

# %% [markdown]
# ### See which cities have less concentration of businesses and focus on increasing businesses in those cities to empower employment and settlement along with giving chances for new businesses to spring up. This can be done using classification of number of businesses per city.

# %% [markdown]
# ### If we had more financial data based on geographics, we can assess which streets and areas are cheap/ costly. Consecutively, one could determine the scale of businesses which could come up in the respective areas.

# %% [markdown]
# ### Analyzing Location start and end date could tell us for how much time the business lasted at one location and if it moved, what factors surround it. Maybe increase in price of commercial places, falling numbers in business or any other reasons.

# %% [markdown]
# ### Tax has to be paid by each and every individual as well as business. Parking and occupancy tax yet remain to be determined on how they are levied (at what rate and conditions, on which businesses specifically) and consequently their effect on businesses

# %% [markdown]
# ### We can use various classification techniques to create training and testing datasets to create prediction models on how an upcoming business would decide to locate its office (city,address,zipcode) to generate maximum outreach and revenue depending on its funding. We could run a regression to see the dependency of factors.
# ### For example, it would pick up a metro city which is not too expensive also while trying to avoid remote areas. It could then choose its office to be in or near downtown to based on its budget and recruitment policies so as to avoid too much expenses in commercial leasing.

# %% [markdown]
# # These are few of the conclusions which I think can be drawn from the data by analyzing the data in more depth. Of course, there is no limit that it ends there. In my opinion we need to split the dataset into training and testing to create prediction models through machine learning.
