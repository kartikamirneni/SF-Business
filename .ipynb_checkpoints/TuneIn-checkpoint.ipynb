# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
tuneindata = pd.read_csv("/Users/Home/Documents/Python Scripts/TuneIn/sf_business_dataset.csv",encoding = "ISO-8859-1")

# %%
print(tuneindata.dtypes)
# Out:
# LocationId                          object
# BusinessAccountNumber                int64
# OwnershipName                       object
# DBAName                             object
# StreetAddress                       object
# City                                object
# State                               object
# SourceZipcode                      float64
# BusinessStartDate                   object
# BusinessEndDate                     object
# LocationStartDate                   object
# LocationEndDate                     object
# MailAddress                         object
# MailCity                            object
# MailZipcode                         object
# MailState                           object
# NAICSCode                           object
# NAICSCodeDescription                object
# ParkingTax                            bool
# TransientOccupancyTax                 bool
# LICCode                             object
# LICCodeDescription                  object
# ...

# %%
tuneindata.head()
# Out:
#        LocationId  BusinessAccountNumber        OwnershipName  DBAName  \
# 0  0026883-11-001                  26883  Chevron Texaco Corp  Chevron
# 1  0026883-12-001                  26883  Chevron Texaco Corp  Chevron
# 2  0026883-13-001                  26883  Chevron Texaco Corp  Chevron
# 3  0026883-15-001                  26883  Chevron Texaco Corp  Chevron
# 4  0026883-16-001                  26883  Chevron Texaco Corp  Chevron
#
#         StreetAddress           City State  SourceZipcode BusinessStartDate  \
# 0    2998 San Jose Av  San Francisco    CA        94112.0        10-01-1968
# 1  301 Claremont Blvd  San Francisco    CA        94127.0        10-01-1968
# 2     3675 Geary Blvd  San Francisco    CA        94118.0        10-01-1968
# 3     2301 Lombard St  San Francisco    CA        94123.0        10-01-1968
# 4        1288 19th St  San Francisco    CA        94107.0        10-01-1968
#
#   BusinessEndDate                        ...                          \
# ...

# %%
# !pip install geopy
# Out:
# ...
#   Running setup.py bdist_wheel for geographiclib: started
#   Running setup.py bdist_wheel for geographiclib: finished with status 'done'
#   Stored in directory: C:\Users\Home\AppData\Local\pip\Cache\wheels\99\45\d1\14954797e2a976083182c2e7da9b4e924509e59b6e5c661061
# Successfully built geographiclib
# ...
# You are using pip version 9.0.1, however version 18.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# !pip install --upgrade pip
# Out:
# ...
#   Found existing installation: pip 9.0.1
#     Uninstalling pip-9.0.1:
#       Successfully uninstalled pip-9.0.1
# Exception:
# Traceback (most recent call last):
#   File "C:\Users\Home\Anaconda3\lib\shutil.py", line 387, in _rmtree_unsafe
#     os.unlink(fullname)
# PermissionError: [WinError 5] Access is denied: 'C:\\Users\\Home\\AppData\\Local\\Temp\\pip-2ctsw_vr-uninstall\\users\\home\\anaconda3\\scripts\\pip.exe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Home\Anaconda3\lib\site-packages\pip\basecommand.py", line 215, in main
#   File "C:\Users\Home\Anaconda3\lib\site-packages\pip\commands\install.py", line 342, in run
#   File "C:\Users\Home\Anaconda3\lib\site-packages\pip\req\req_set.py", line 795, in install
#   File "C:\Users\Home\Anaconda3\lib\site-packages\pip\req\req_install.py", line 767, in commit_uninstall
# ...

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="my-application")

tuneindata['BusinessLocation'] = [geolocator.geocode(x, timeout = 60) for x in tuneindata['DBAName']]
x = tuneindata['BusinessLocation']
tuneindata.dropna(subset=['BusinessLocation'], inplace=True)
tuneindata['g_latitude'] = tuneindata['BusinessLocation'].apply(lambda loc: loc.latitude)
tuneindata['g_longitude'] = tuneindata['BusinessLocation'].apply(lambda loc: loc.longitude)
tuneindata
